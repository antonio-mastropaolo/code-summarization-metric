# %%
setwd("/Users/mdipenta/summarization-metric")
t<-read.csv("human-annotated-dataset-with-metrics.csv")

# %%
summary(t)
# Out:
#        X                        user_id      question_id         mid
#  Min.   :   0   Zfu08dIuWInAu4nIUNDz: 129   Min.   :  0.0   Min.   :0.000
#  1st Qu.:1563   cleAq2ioAlfn0f46Mm1C: 127   1st Qu.:166.0   1st Qu.:1.000
#  Median :3126   VCo3HFgiyVv5UMdQt4p3: 104   Median :260.0   Median :3.000
#  Mean   :3126   8aeVM4TTAhmAI07Y3jDW:  76   Mean   :245.4   Mean   :2.511
#  3rd Qu.:4689   3J3rAMDmdaycnd5PwWgz:  71   3rd Qu.:356.0   3rd Qu.:4.000
#  Max.   :6252   XFvy1ChD65gtfDauQ3eI:  71   Max.   :445.0   Max.   :5.000
#                 (Other)             :5675
#  Overall.DA.Score Content.Adequacy  Conciseness       Fluency
#  Min.   :  0.00   Min.   :0.000    Min.   :0.000   Min.   :0.00
#  1st Qu.:  5.00   1st Qu.:1.000    1st Qu.:2.000   1st Qu.:2.00
#  Median : 45.00   Median :3.000    Median :3.000   Median :4.00
#  Mean   : 44.54   Mean   :2.736    Mean   :3.179   Mean   :3.37
#  3rd Qu.: 78.00   3rd Qu.:4.000    3rd Qu.:5.000   3rd Qu.:5.00
#  Max.   :100.00   Max.   :5.000    Max.   :5.000   Max.   :5.00
#
#   sourcerer_id                                            codeComment
#  Min.   :  250715   returns the value of the code property      : 190
#  1st Qu.:18925873   sets the value of the code property         :  98
#  Median :27798040   sets the value of the field                 :  76
#  Mean   :27561228   sets the value of the column                :  65
#  3rd Qu.:40092175   auto generated setter method                :  59
#  Max.   :51576809   creates a new adapter for an object of class:  53
#                     (Other)                                     :5712
#                                                                                                                             codeFunctions
#  \tpublic Integer getNodeID(QueryGraphNode n) {\n\t\treturn nodeID.get(n);\n\t}\n                                                         :  42
#  public void setBase64Chunks(Collection iBase64Chunks) {\n\t\tthis.iBase64Chunks = iBase64Chunks;\n\t\trefreshBase64String(true);\n\t}    :  35
#  \tpublic boolean isMax() {\n\t\treturn (m_level == Z_MAX);\n\t}\n                                                                        :  30
#  \tpublic void setCheckStp() {\n\t\tchkStp.setSelected(true);\n\t}\n                                                                      :  30
#    public LoginError findLoginErrorByID(String id) {\n    return (LoginError)this.getHibernateTemplate().get(LoginError.class, id);\n  }\n:  30
#  \t public State createState(String name, State parent){\n\t\t\treturn machine.createState(name,parent);\n\t }\n                          :  24
#  (Other)                                                                                                                                  :6062
#                                                 originalComment
#  auto generated setter method                           :  71
#  creates a new adapter for an object of class           :  64
#  get the index of a given node in this schema           :  42
#  change the text of the label                           :  36
#  sets the collection of base 64 chunks held by this bean:  35
#  test method for                                        :  34
#  (Other)                                                :5971
#     jaccard           bleu.A           bleu.1            bleu.2
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.01066   Min.   :0.0000
#  1st Qu.:0.1333   1st Qu.:0.2012   1st Qu.:0.44231   1st Qu.:0.2450
#  Median :0.3000   Median :0.3762   Median :0.62064   Median :0.4094
#  Mean   :0.4289   Mean   :0.4760   Mean   :0.63380   Mean   :0.5053
#  3rd Qu.:0.7500   3rd Qu.:0.8154   3rd Qu.:0.86083   3rd Qu.:0.8276
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.00000   Max.   :1.0000
#
#      bleu.3           bleu.4        tfidf_cosine    USE_cosine_similarity
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :-0.08398
#  1st Qu.:0.1563   1st Qu.:0.1131   1st Qu.:0.1660   1st Qu.: 0.34861
#  Median :0.3333   Median :0.2806   Median :0.3721   Median : 0.58650
#  Mean   :0.4483   Mean   :0.4181   Mean   :0.4651   Mean   : 0.59429
#  3rd Qu.:0.8046   3rd Qu.:0.7778   3rd Qu.:0.8182   3rd Qu.: 0.89409
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.0000   Max.   : 1.00000
#
#  bert.score.precision bert.score.recall bert.score.f1
#  Min.   :-0.4545      Min.   :-0.3759   Min.   :-0.3053
#  1st Qu.: 0.2135      1st Qu.: 0.1363   1st Qu.: 0.1850
#  Median : 0.4244      Median : 0.3488   Median : 0.3759
#  Mean   : 0.4899      Mean   : 0.4354   Mean   : 0.4622
#  3rd Qu.: 0.8580      3rd Qu.: 0.7951   3rd Qu.: 0.8089
#  Max.   : 1.0000      Max.   : 1.0000   Max.   : 1.0000
#
#  sentence_bert_cosine_similarity infersent_cosine_similarity     meteor
#  Min.   :-0.02066                Min.   :0.2022              Min.   :0.0000
#  1st Qu.: 0.38483                1st Qu.:0.6096              1st Qu.:0.1415
#  Median : 0.63377                Median :0.7295              Median :0.3333
#  Mean   : 0.62952                Mean   :0.7420              Mean   :0.4581
#  3rd Qu.: 0.92447                3rd Qu.:0.8897              3rd Qu.:0.8737
#  Max.   : 1.00000                Max.   :1.0000              Max.   :1.2500
#
#    rouge.l.f1
#  Min.   :0.0000
#  1st Qu.:0.3333
#  Median :0.5252
#  Mean   :0.5626
#  3rd Qu.:0.8807
#  Max.   :1.0000
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                    tokenized_function
#  public integer get node id query graph node n return node id get n                                                                                                                                                                                                                                                                                                                                                                                         :  42
#  public void set base64 chunks collection i base64 chunks this i base64 chunks i base64 chunks refresh base64 string true                                                                                                                                                                                                                                                                                                                                   :  35
#  public boolean is max return m level z max                                                                                                                                                                                                                                                                                                                                                                                                                 :  30
#  public login error find login error by id string id return login error this get hibernate template get login error class id                                                                                                                                                                                                                                                                                                                                :  30
#  public void set check stp chk stp set selected true                                                                                                                                                                                                                                                                                                                                                                                                        :  30
#  private jbutton get jbutton references add if j button references add null j button references add new jbutton j button references add set icon new image icon get class get resource path image arrow up png j button references add set size 15 15 j button references add set tool tip text objekt hinzuf gen j button references add set action command onto object add j button references add add action listener this return j button references add:  24
#  (Other)                                                                                                                                                                                                                                                                                                                                                                                                                                                    :6062
#     c_coeff         lenComment          num          rouge.1.f1
#  Min.   :0.0000   Min.   : 3.000   Min.   :0.000   Min.   :0.0000
#  1st Qu.:0.2900   1st Qu.: 5.000   1st Qu.:2.000   1st Qu.:0.2857
#  Median :0.5000   Median : 7.000   Median :3.000   Median :0.4706
#  Mean   :0.4686   Mean   : 6.665   Mean   :2.938   Mean   :0.5350
#  3rd Qu.:0.6700   3rd Qu.: 8.000   3rd Qu.:4.000   3rd Qu.:0.8571
#  Max.   :1.0000   Max.   :13.000   Max.   :9.000   Max.   :1.0000
#
#    rouge.1.p        rouge.1.r        rouge.2.f1       rouge.2.p
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.000
#  1st Qu.:0.2500   1st Qu.:0.2857   1st Qu.:0.0000   1st Qu.:0.000
#  Median :0.4545   Median :0.5000   Median :0.2000   Median :0.200
#  Mean   :0.5249   Mean   :0.5799   Mean   :0.3687   Mean   :0.363
#  3rd Qu.:0.8750   3rd Qu.:1.0000   3rd Qu.:0.8000   3rd Qu.:0.800
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.0000   Max.   :1.000
#
#    rouge.2.r        rouge.3.f1       rouge.3.p        rouge.3.r
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000
#  Median :0.2000   Median :0.0000   Median :0.0000   Median :0.0000
#  Mean   :0.3961   Mean   :0.2977   Mean   :0.2955   Mean   :0.3153
#  3rd Qu.:1.0000   3rd Qu.:0.7143   3rd Qu.:0.7143   3rd Qu.:1.0000
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.0000   Max.   :1.0000
#
#    rouge.4.f1       rouge.4.p        rouge.4.r        rouge.l.p
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.3150
#  Median :0.0000   Median :0.0000   Median :0.0000   Median :0.4936
#  Mean   :0.2484   Mean   :0.2463   Mean   :0.2621   Mean   :0.5515
#  3rd Qu.:0.4000   3rd Qu.:0.3333   3rd Qu.:0.6667   3rd Qu.:0.8947
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.0000   Max.   :1.0000
#
#    rouge.l.r        rouge.w.f1       rouge.w.p        rouge.w.r
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.3521   1st Qu.:0.2056   1st Qu.:0.2457   1st Qu.:0.1725
#  Median :0.5612   Median :0.3408   Median :0.4000   Median :0.3309
#  Mean   :0.6002   Mean   :0.4176   Mean   :0.4970   Mean   :0.3831
#  3rd Qu.:1.0000   3rd Qu.:0.6956   3rd Qu.:0.8571   3rd Qu.:0.6190
#  Max.   :1.0000   Max.   :0.8906   Max.   :1.0000   Max.   :0.8027
#
#  tfidf_euclidean    chrf_score      USE_euclidean_distance
#  Min.   :0.0000   Min.   :0.02834   Min.   :0.0000001
#  1st Qu.:0.6030   1st Qu.:0.20064   1st Qu.:0.4602355
#  Median :1.1206   Median :0.37011   Median :0.9093925
#  Mean   :0.8936   Mean   :0.48532   Mean   :0.7652932
#  3rd Qu.:1.2915   3rd Qu.:0.82619   3rd Qu.:1.1413958
#  Max.   :1.4142   Max.   :1.00000   Max.   :1.4723974
#
#  sentence_bert_euclidean_distance infersent_euclidean_distance
#  Min.   : 0.00                    Min.   :0.000
#  1st Qu.:10.91                    1st Qu.:1.532
#  Median :23.75                    Median :2.413
#  Mean   :20.07                    Mean   :1.994
#  3rd Qu.:30.58                    3rd Qu.:2.841
#  Max.   :40.04                    Max.   :4.197
#
#  CodeT5.plus.cosine.similarity   SIDE_HARD        SIDE_TRIVIAL
#  Min.   :0.1199                Min.   :-0.8151   Min.   :-0.8027
#  1st Qu.:0.4052                1st Qu.: 0.6485   1st Qu.: 0.6542
#  Median :0.4612                Median : 0.8477   Median : 0.8543
#  Mean   :0.4585                Mean   : 0.7322   Mean   : 0.7454
#  3rd Qu.:0.5236                3rd Qu.: 0.9357   3rd Qu.: 0.9442
#  Max.   :0.6951                Max.   : 0.9961   Max.   : 0.9970

# %%
newHeader=c("X","user_id", "question_id", "mid", "Overall DA Score", "Content Adequacy",
       	"Conciseness", "Fluency", "sourcerer_id", "codeComment",
       	"codeFunctions", "originalComment", "Jaccard","BLEU-A",
       	"BLEU-1","BLEU-2","BLEU-3","BLEU-4","TF_IDF_CS","USE_CS",
		"BERTScore-P","BERTScore-R","BERTScore-F1","SentenceBERT_CS",
		"InferSent_CS","METEOR","ROUGE-L-F1", "tokenized_function", "c_coeff", "lenComment","num",
		"ROUGE-1-F1","ROUGE-1-P","ROUGE-1-R","ROUGE-2-F1","ROUGE-2-P","ROUGE-2-R","ROUGE-3-F1","ROUGE-3-P","ROUGE-3-R",
       	"ROUGE-4-F1","ROUGE-4-P","ROUGE-4-R","ROUGE-L-P","ROUGE-L-R","ROUGE-W-F1","ROUGE-W-P","ROUGE-W-R","TF_IDF_ED","chrF",
		"USE_ED","SentenceBERT_ED","InferSent_ED","CodeT5-plus_CS","SIDE","SIDE Trivial")

# %%
for(x in 1:length(t))
{
    colnames(t)[x]<-newHeader[x]
}

# %%
summary(t)
# Out:
#        X                        user_id      question_id         mid
#  Min.   :   0   Zfu08dIuWInAu4nIUNDz: 129   Min.   :  0.0   Min.   :0.000
#  1st Qu.:1563   cleAq2ioAlfn0f46Mm1C: 127   1st Qu.:166.0   1st Qu.:1.000
#  Median :3126   VCo3HFgiyVv5UMdQt4p3: 104   Median :260.0   Median :3.000
#  Mean   :3126   8aeVM4TTAhmAI07Y3jDW:  76   Mean   :245.4   Mean   :2.511
#  3rd Qu.:4689   3J3rAMDmdaycnd5PwWgz:  71   3rd Qu.:356.0   3rd Qu.:4.000
#  Max.   :6252   XFvy1ChD65gtfDauQ3eI:  71   Max.   :445.0   Max.   :5.000
#                 (Other)             :5675
#  Overall DA Score Content Adequacy  Conciseness       Fluency
#  Min.   :  0.00   Min.   :0.000    Min.   :0.000   Min.   :0.00
#  1st Qu.:  5.00   1st Qu.:1.000    1st Qu.:2.000   1st Qu.:2.00
#  Median : 45.00   Median :3.000    Median :3.000   Median :4.00
#  Mean   : 44.54   Mean   :2.736    Mean   :3.179   Mean   :3.37
#  3rd Qu.: 78.00   3rd Qu.:4.000    3rd Qu.:5.000   3rd Qu.:5.00
#  Max.   :100.00   Max.   :5.000    Max.   :5.000   Max.   :5.00
#
#   sourcerer_id                                            codeComment
#  Min.   :  250715   returns the value of the code property      : 190
#  1st Qu.:18925873   sets the value of the code property         :  98
#  Median :27798040   sets the value of the field                 :  76
#  Mean   :27561228   sets the value of the column                :  65
#  3rd Qu.:40092175   auto generated setter method                :  59
#  Max.   :51576809   creates a new adapter for an object of class:  53
#                     (Other)                                     :5712
#                                                                                                                             codeFunctions
#  \tpublic Integer getNodeID(QueryGraphNode n) {\n\t\treturn nodeID.get(n);\n\t}\n                                                         :  42
#  public void setBase64Chunks(Collection iBase64Chunks) {\n\t\tthis.iBase64Chunks = iBase64Chunks;\n\t\trefreshBase64String(true);\n\t}    :  35
#  \tpublic boolean isMax() {\n\t\treturn (m_level == Z_MAX);\n\t}\n                                                                        :  30
#  \tpublic void setCheckStp() {\n\t\tchkStp.setSelected(true);\n\t}\n                                                                      :  30
#    public LoginError findLoginErrorByID(String id) {\n    return (LoginError)this.getHibernateTemplate().get(LoginError.class, id);\n  }\n:  30
#  \t public State createState(String name, State parent){\n\t\t\treturn machine.createState(name,parent);\n\t }\n                          :  24
#  (Other)                                                                                                                                  :6062
#                                                 originalComment
#  auto generated setter method                           :  71
#  creates a new adapter for an object of class           :  64
#  get the index of a given node in this schema           :  42
#  change the text of the label                           :  36
#  sets the collection of base 64 chunks held by this bean:  35
#  test method for                                        :  34
#  (Other)                                                :5971
#     Jaccard           BLEU-A           BLEU-1            BLEU-2
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.01066   Min.   :0.0000
#  1st Qu.:0.1333   1st Qu.:0.2012   1st Qu.:0.44231   1st Qu.:0.2450
#  Median :0.3000   Median :0.3762   Median :0.62064   Median :0.4094
#  Mean   :0.4289   Mean   :0.4760   Mean   :0.63380   Mean   :0.5053
#  3rd Qu.:0.7500   3rd Qu.:0.8154   3rd Qu.:0.86083   3rd Qu.:0.8276
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.00000   Max.   :1.0000
#
#      BLEU-3           BLEU-4         TF_IDF_CS          USE_CS
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :-0.08398
#  1st Qu.:0.1563   1st Qu.:0.1131   1st Qu.:0.1660   1st Qu.: 0.34861
#  Median :0.3333   Median :0.2806   Median :0.3721   Median : 0.58650
#  Mean   :0.4483   Mean   :0.4181   Mean   :0.4651   Mean   : 0.59429
#  3rd Qu.:0.8046   3rd Qu.:0.7778   3rd Qu.:0.8182   3rd Qu.: 0.89409
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.0000   Max.   : 1.00000
#
#   BERTScore-P       BERTScore-R       BERTScore-F1     SentenceBERT_CS
#  Min.   :-0.4545   Min.   :-0.3759   Min.   :-0.3053   Min.   :-0.02066
#  1st Qu.: 0.2135   1st Qu.: 0.1363   1st Qu.: 0.1850   1st Qu.: 0.38483
#  Median : 0.4244   Median : 0.3488   Median : 0.3759   Median : 0.63377
#  Mean   : 0.4899   Mean   : 0.4354   Mean   : 0.4622   Mean   : 0.62952
#  3rd Qu.: 0.8580   3rd Qu.: 0.7951   3rd Qu.: 0.8089   3rd Qu.: 0.92447
#  Max.   : 1.0000   Max.   : 1.0000   Max.   : 1.0000   Max.   : 1.00000
#
#   InferSent_CS        METEOR         ROUGE-L-F1
#  Min.   :0.2022   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.6096   1st Qu.:0.1415   1st Qu.:0.3333
#  Median :0.7295   Median :0.3333   Median :0.5252
#  Mean   :0.7420   Mean   :0.4581   Mean   :0.5626
#  3rd Qu.:0.8897   3rd Qu.:0.8737   3rd Qu.:0.8807
#  Max.   :1.0000   Max.   :1.2500   Max.   :1.0000
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                    tokenized_function
#  public integer get node id query graph node n return node id get n                                                                                                                                                                                                                                                                                                                                                                                         :  42
#  public void set base64 chunks collection i base64 chunks this i base64 chunks i base64 chunks refresh base64 string true                                                                                                                                                                                                                                                                                                                                   :  35
#  public boolean is max return m level z max                                                                                                                                                                                                                                                                                                                                                                                                                 :  30
#  public login error find login error by id string id return login error this get hibernate template get login error class id                                                                                                                                                                                                                                                                                                                                :  30
#  public void set check stp chk stp set selected true                                                                                                                                                                                                                                                                                                                                                                                                        :  30
#  private jbutton get jbutton references add if j button references add null j button references add new jbutton j button references add set icon new image icon get class get resource path image arrow up png j button references add set size 15 15 j button references add set tool tip text objekt hinzuf gen j button references add set action command onto object add j button references add add action listener this return j button references add:  24
#  (Other)                                                                                                                                                                                                                                                                                                                                                                                                                                                    :6062
#     c_coeff         lenComment          num          ROUGE-1-F1
#  Min.   :0.0000   Min.   : 3.000   Min.   :0.000   Min.   :0.0000
#  1st Qu.:0.2900   1st Qu.: 5.000   1st Qu.:2.000   1st Qu.:0.2857
#  Median :0.5000   Median : 7.000   Median :3.000   Median :0.4706
#  Mean   :0.4686   Mean   : 6.665   Mean   :2.938   Mean   :0.5350
#  3rd Qu.:0.6700   3rd Qu.: 8.000   3rd Qu.:4.000   3rd Qu.:0.8571
#  Max.   :1.0000   Max.   :13.000   Max.   :9.000   Max.   :1.0000
#
#    ROUGE-1-P        ROUGE-1-R        ROUGE-2-F1       ROUGE-2-P
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.000
#  1st Qu.:0.2500   1st Qu.:0.2857   1st Qu.:0.0000   1st Qu.:0.000
#  Median :0.4545   Median :0.5000   Median :0.2000   Median :0.200
#  Mean   :0.5249   Mean   :0.5799   Mean   :0.3687   Mean   :0.363
#  3rd Qu.:0.8750   3rd Qu.:1.0000   3rd Qu.:0.8000   3rd Qu.:0.800
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.0000   Max.   :1.000
#
#    ROUGE-2-R        ROUGE-3-F1       ROUGE-3-P        ROUGE-3-R
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000
#  Median :0.2000   Median :0.0000   Median :0.0000   Median :0.0000
#  Mean   :0.3961   Mean   :0.2977   Mean   :0.2955   Mean   :0.3153
#  3rd Qu.:1.0000   3rd Qu.:0.7143   3rd Qu.:0.7143   3rd Qu.:1.0000
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.0000   Max.   :1.0000
#
#    ROUGE-4-F1       ROUGE-4-P        ROUGE-4-R        ROUGE-L-P
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.3150
#  Median :0.0000   Median :0.0000   Median :0.0000   Median :0.4936
#  Mean   :0.2484   Mean   :0.2463   Mean   :0.2621   Mean   :0.5515
#  3rd Qu.:0.4000   3rd Qu.:0.3333   3rd Qu.:0.6667   3rd Qu.:0.8947
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.0000   Max.   :1.0000
#
#    ROUGE-L-R        ROUGE-W-F1       ROUGE-W-P        ROUGE-W-R
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.3521   1st Qu.:0.2056   1st Qu.:0.2457   1st Qu.:0.1725
#  Median :0.5612   Median :0.3408   Median :0.4000   Median :0.3309
#  Mean   :0.6002   Mean   :0.4176   Mean   :0.4970   Mean   :0.3831
#  3rd Qu.:1.0000   3rd Qu.:0.6956   3rd Qu.:0.8571   3rd Qu.:0.6190
#  Max.   :1.0000   Max.   :0.8906   Max.   :1.0000   Max.   :0.8027
#
#    TF_IDF_ED           chrF             USE_ED          SentenceBERT_ED
#  Min.   :0.0000   Min.   :0.02834   Min.   :0.0000001   Min.   : 0.00
#  1st Qu.:0.6030   1st Qu.:0.20064   1st Qu.:0.4602355   1st Qu.:10.91
#  Median :1.1206   Median :0.37011   Median :0.9093925   Median :23.75
#  Mean   :0.8936   Mean   :0.48532   Mean   :0.7652932   Mean   :20.07
#  3rd Qu.:1.2915   3rd Qu.:0.82619   3rd Qu.:1.1413958   3rd Qu.:30.58
#  Max.   :1.4142   Max.   :1.00000   Max.   :1.4723974   Max.   :40.04
#
#   InferSent_ED   CodeT5-plus_CS        SIDE          SIDE Trivial
#  Min.   :0.000   Min.   :0.1199   Min.   :-0.8151   Min.   :-0.8027
#  1st Qu.:1.532   1st Qu.:0.4052   1st Qu.: 0.6485   1st Qu.: 0.6542
#  Median :2.413   Median :0.4612   Median : 0.8477   Median : 0.8543
#  Mean   :1.994   Mean   :0.4585   Mean   : 0.7322   Mean   : 0.7454
#  3rd Qu.:2.841   3rd Qu.:0.5236   3rd Qu.: 0.9357   3rd Qu.: 0.9442
#  Max.   :4.197   Max.   :0.6951   Max.   : 0.9961   Max.   : 0.9970

# %%
userMetrics<-c("Overall DA Score","Content Adequacy","Conciseness","Fluency")
evalMetrics=c("Jaccard","BLEU-A","BLEU-1","BLEU-2","BLEU-3","BLEU-4","TF_IDF_CS","USE_CS",
"BERTScore-P","BERTScore-R","BERTScore-F1","SentenceBERT_CS","InferSent_CS",
"METEOR","ROUGE-L-F1","c_coeff",
"ROUGE-1-F1","ROUGE-1-P","ROUGE-1-R","ROUGE-2-F1","ROUGE-2-P","ROUGE-2-R","ROUGE-3-F1","ROUGE-3-P","ROUGE-3-R","ROUGE-4-F1",
"ROUGE-4-P","ROUGE-4-R","ROUGE-L-P","ROUGE-L-R","ROUGE-W-F1","ROUGE-W-P","ROUGE-W-R","TF_IDF_ED","chrF",
"USE_ED","SentenceBERT_ED","InferSent_ED","CodeT5-plus_CS","SIDE")
allMetrics=c(userMetrics,evalMetrics)
tsum<-subset(t,t$mid!=0)
attach(tsum,warn.conflicts=FALSE)

# %%
summary(tsum)
# Out:
#        X                        user_id      question_id         mid
#  Min.   :   0   Zfu08dIuWInAu4nIUNDz: 109   Min.   :  0.0   Min.   :1.000
#  1st Qu.:1566   cleAq2ioAlfn0f46Mm1C: 105   1st Qu.:166.0   1st Qu.:2.000
#  Median :3128   VCo3HFgiyVv5UMdQt4p3:  86   Median :260.0   Median :3.000
#  Mean   :3126   8aeVM4TTAhmAI07Y3jDW:  64   Mean   :245.2   Mean   :3.018
#  3rd Qu.:4690   3J3rAMDmdaycnd5PwWgz:  59   3rd Qu.:356.0   3rd Qu.:4.000
#  Max.   :6252   XFvy1ChD65gtfDauQ3eI:  59   Max.   :445.0   Max.   :5.000
#                 (Other)             :4719
#  Overall DA Score Content Adequacy  Conciseness       Fluency
#  Min.   :  0.00   Min.   :0.000    Min.   :0.000   Min.   :0.000
#  1st Qu.:  5.00   1st Qu.:1.000    1st Qu.:2.000   1st Qu.:2.000
#  Median : 40.00   Median :3.000    Median :3.000   Median :4.000
#  Mean   : 42.54   Mean   :2.655    Mean   :3.159   Mean   :3.351
#  3rd Qu.: 75.00   3rd Qu.:4.000    3rd Qu.:5.000   3rd Qu.:5.000
#  Max.   :100.00   Max.   :5.000    Max.   :5.000   Max.   :5.000
#
#   sourcerer_id                                      codeComment
#  Min.   :  250715   returns the value of the code property: 190
#  1st Qu.:18925873   sets the value of the code property   :  98
#  Median :27798040   sets the value of the field           :  76
#  Mean   :27562161   sets the value of the column          :  65
#  3rd Qu.:40092175   returns the current node              :  52
#  Max.   :51576809   auto generated setter method          :  48
#                     (Other)                               :4672
#                                                                                                                             codeFunctions
#  \tpublic Integer getNodeID(QueryGraphNode n) {\n\t\treturn nodeID.get(n);\n\t}\n                                                         :  35
#  public void setBase64Chunks(Collection iBase64Chunks) {\n\t\tthis.iBase64Chunks = iBase64Chunks;\n\t\trefreshBase64String(true);\n\t}    :  30
#  \tpublic boolean isMax() {\n\t\treturn (m_level == Z_MAX);\n\t}\n                                                                        :  25
#  \tpublic void setCheckStp() {\n\t\tchkStp.setSelected(true);\n\t}\n                                                                      :  25
#    public LoginError findLoginErrorByID(String id) {\n    return (LoginError)this.getHibernateTemplate().get(LoginError.class, id);\n  }\n:  25
#  \t public State createState(String name, State parent){\n\t\t\treturn machine.createState(name,parent);\n\t }\n                          :  20
#  (Other)                                                                                                                                  :5041
#                                                 originalComment
#  auto generated setter method                           :  60
#  creates a new adapter for an object of class           :  53
#  get the index of a given node in this schema           :  35
#  change the text of the label                           :  30
#  sets the collection of base 64 chunks held by this bean:  30
#  test method for                                        :  28
#  (Other)                                                :4965
#     Jaccard           BLEU-A           BLEU-1            BLEU-2
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.01066   Min.   :0.0000
#  1st Qu.:0.1111   1st Qu.:0.1763   1st Qu.:0.40440   1st Qu.:0.2195
#  Median :0.2500   Median :0.3159   Median :0.56248   Median :0.3506
#  Mean   :0.3133   Mean   :0.3701   Mean   :0.55973   Mean   :0.4053
#  3rd Qu.:0.4286   3rd Qu.:0.5024   3rd Qu.:0.69967   3rd Qu.:0.5333
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.00000   Max.   :1.0000
#
#      BLEU-3           BLEU-4          TF_IDF_CS          USE_CS
#  Min.   :0.0000   Min.   :0.00000   Min.   :0.0000   Min.   :-0.08398
#  1st Qu.:0.1349   1st Qu.:0.09091   1st Qu.:0.1375   1st Qu.: 0.29629
#  Median :0.2628   Median :0.21622   Median :0.2996   Median : 0.50974
#  Mean   :0.3367   Mean   :0.30046   Mean   :0.3569   Mean   : 0.51222
#  3rd Qu.:0.4667   3rd Qu.:0.41713   3rd Qu.:0.5193   3rd Qu.: 0.72185
#  Max.   :1.0000   Max.   :1.00000   Max.   :1.0000   Max.   : 1.00000
#
#   BERTScore-P       BERTScore-R       BERTScore-F1     SentenceBERT_CS
#  Min.   :-0.4545   Min.   :-0.3759   Min.   :-0.3053   Min.   :-0.02066
#  1st Qu.: 0.1751   1st Qu.: 0.1011   1st Qu.: 0.1528   1st Qu.: 0.34604
#  Median : 0.3511   Median : 0.2789   Median : 0.3098   Median : 0.54491
#  Mean   : 0.3867   Mean   : 0.3212   Mean   : 0.3534   Mean   : 0.55458
#  3rd Qu.: 0.5810   3rd Qu.: 0.4770   3rd Qu.: 0.5076   3rd Qu.: 0.74510
#  Max.   : 1.0000   Max.   : 1.0000   Max.   : 1.0000   Max.   : 1.00000
#
#   InferSent_CS        METEOR         ROUGE-L-F1
#  Min.   :0.2022   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.5872   1st Qu.:0.1181   1st Qu.:0.2878
#  Median :0.6942   Median :0.2500   Median :0.4435
#  Mean   :0.6898   Mean   :0.3492   Mean   :0.4750
#  3rd Qu.:0.7840   3rd Qu.:0.5011   3rd Qu.:0.6538
#  Max.   :1.0000   Max.   :1.2500   Max.   :1.0000
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                    tokenized_function
#  public integer get node id query graph node n return node id get n                                                                                                                                                                                                                                                                                                                                                                                         :  35
#  public void set base64 chunks collection i base64 chunks this i base64 chunks i base64 chunks refresh base64 string true                                                                                                                                                                                                                                                                                                                                   :  30
#  public boolean is max return m level z max                                                                                                                                                                                                                                                                                                                                                                                                                 :  25
#  public login error find login error by id string id return login error this get hibernate template get login error class id                                                                                                                                                                                                                                                                                                                                :  25
#  public void set check stp chk stp set selected true                                                                                                                                                                                                                                                                                                                                                                                                        :  25
#  private jbutton get jbutton references add if j button references add null j button references add new jbutton j button references add set icon new image icon get class get resource path image arrow up png j button references add set size 15 15 j button references add set tool tip text objekt hinzuf gen j button references add set action command onto object add j button references add add action listener this return j button references add:  20
#  (Other)                                                                                                                                                                                                                                                                                                                                                                                                                                                    :5041
#     c_coeff         lenComment          num          ROUGE-1-F1
#  Min.   :0.0000   Min.   : 3.000   Min.   :0.000   Min.   :0.0000
#  1st Qu.:0.2900   1st Qu.: 5.000   1st Qu.:2.000   1st Qu.:0.2500
#  Median :0.5000   Median : 7.000   Median :3.000   Median :0.4000
#  Mean   :0.4703   Mean   : 6.512   Mean   :2.882   Mean   :0.4420
#  3rd Qu.:0.6700   3rd Qu.: 8.000   3rd Qu.:4.000   3rd Qu.:0.6154
#  Max.   :1.0000   Max.   :12.000   Max.   :9.000   Max.   :1.0000
#
#    ROUGE-1-P       ROUGE-1-R        ROUGE-2-F1       ROUGE-2-P
#  Min.   :0.000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.250   1st Qu.:0.2500   1st Qu.:0.0000   1st Qu.:0.0000
#  Median :0.375   Median :0.4444   Median :0.1429   Median :0.1111
#  Mean   :0.430   Mean   :0.4955   Mean   :0.2425   Mean   :0.2357
#  3rd Qu.:0.600   3rd Qu.:0.7500   3rd Qu.:0.3636   3rd Qu.:0.3333
#  Max.   :1.000   Max.   :1.0000   Max.   :1.0000   Max.   :1.0000
#
#    ROUGE-2-R        ROUGE-3-F1       ROUGE-3-P        ROUGE-3-R
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000
#  Median :0.1667   Median :0.0000   Median :0.0000   Median :0.0000
#  Mean   :0.2754   Mean   :0.1572   Mean   :0.1546   Mean   :0.1782
#  3rd Qu.:0.5000   3rd Qu.:0.1667   3rd Qu.:0.1429   3rd Qu.:0.2000
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.0000   Max.   :1.0000
#
#    ROUGE-4-F1       ROUGE-4-P        ROUGE-4-R        ROUGE-L-P
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.2855
#  Median :0.0000   Median :0.0000   Median :0.0000   Median :0.4003
#  Mean   :0.1121   Mean   :0.1097   Mean   :0.1287   Mean   :0.4618
#  3rd Qu.:0.0000   3rd Qu.:0.0000   3rd Qu.:0.0000   3rd Qu.:0.6273
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.0000   Max.   :1.0000
#
#    ROUGE-L-R        ROUGE-W-F1       ROUGE-W-P        ROUGE-W-R
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.3150   1st Qu.:0.1863   1st Qu.:0.2079   1st Qu.:0.1649
#  Median :0.4936   Median :0.2917   Median :0.3333   Median :0.2676
#  Mean   :0.5197   Mean   :0.3389   Mean   :0.3964   Mean   :0.3228
#  3rd Qu.:0.7868   3rd Qu.:0.4767   3rd Qu.:0.5406   3rd Qu.:0.5166
#  Max.   :1.0000   Max.   :0.8906   Max.   :1.0000   Max.   :0.8027
#
#    TF_IDF_ED           chrF             USE_ED          SentenceBERT_ED
#  Min.   :0.0000   Min.   :0.02834   Min.   :0.0000001   Min.   : 0.00
#  1st Qu.:0.9805   1st Qu.:0.17990   1st Qu.:0.7458557   1st Qu.:19.69
#  Median :1.1836   Median :0.30154   Median :0.9902129   Median :26.04
#  Mean   :1.0743   Mean   :0.38122   Mean   :0.9200881   Mean   :24.13
#  3rd Qu.:1.3134   3rd Qu.:0.49829   3rd Qu.:1.1863453   3rd Qu.:31.45
#  Max.   :1.4142   Max.   :1.00000   Max.   :1.4723974   Max.   :40.04
#
#   InferSent_ED   CodeT5-plus_CS        SIDE          SIDE Trivial
#  Min.   :0.000   Min.   :0.1199   Min.   :-0.8151   Min.   :-0.8027
#  1st Qu.:2.159   1st Qu.:0.4023   1st Qu.: 0.6367   1st Qu.: 0.6474
#  Median :2.564   Median :0.4575   Median : 0.8476   Median : 0.8560
#  Mean   :2.397   Mean   :0.4557   Mean   : 0.7278   Mean   : 0.7414
#  3rd Qu.:2.917   3rd Qu.:0.5197   3rd Qu.: 0.9360   3rd Qu.: 0.9442
#  Max.   :4.197   Max.   :0.6951   Max.   : 0.9961   Max.   : 0.9970

# %%
attach(tsum,warn.conflicts=FALSE)

tx<-subset(tsum,select=userMetrics)
cor(tx,method="spearman")
# Out:
#                  Overall DA Score Content Adequacy Conciseness Fluency
# Overall DA Score 1.0000000        0.8326999        0.6074156   0.5339615
# Content Adequacy 0.8326999        1.0000000        0.6600880   0.5675665
# Conciseness      0.6074156        0.6600880        1.0000000   0.6622104
# Fluency          0.5339615        0.5675665        0.6622104   1.0000000

# %%
tmet<-subset(tsum,select=evalMetrics)
cor(tmet,method="spearman")
# Out:
#                 Jaccard     BLEU-A     BLEU-1      BLEU-2      BLEU-3
# Jaccard          1.00000000  0.8637683  0.49873136  0.81748268  0.8950030
# BLEU-A           0.86376830  1.0000000  0.77345855  0.98332604  0.9930031
# BLEU-1           0.49873136  0.7734585  1.00000000  0.82274039  0.7150084
# BLEU-2           0.81748268  0.9833260  0.82274039  1.00000000  0.9683129
# BLEU-3           0.89500298  0.9930031  0.71500840  0.96831289  1.0000000
# BLEU-4           0.91130481  0.9822595  0.67292027  0.94463141  0.9921999
# TF_IDF_CS        0.95596391  0.8253704  0.46914707  0.77866528  0.8556493
# USE_CS           0.85751385  0.8272855  0.50854072  0.79560654  0.8529096
# BERTScore-P      0.77083343  0.7047391  0.45758165  0.67815024  0.7289489
# BERTScore-R      0.74611117  0.7838272  0.60395433  0.76984803  0.7919977
# BERTScore-F1     0.79792939  0.7797044  0.54639460  0.75745573  0.7979699
# SentenceBERT_CS  0.78094529  0.7389125  0.43068791  0.71212623  0.7683932
# InferSent_CS     0.82385171  0.7598368  0.47542350  0.73438641  0.7810289
# METEOR           0.89874910  0.8660135  0.53835756  0.82782481  0.8894969
# ROUGE-L-F1       0.86935666  0.7823405  0.47273785  0.74637653  0.8150051
# c_coeff          0.29446425  0.2089534 -0.03758200  0.17920861  0.2412030
# ROUGE-1-F1       0.88216758  0.8015337  0.48946854  0.77018736  0.8336101
# ROUGE-1-P        0.83138597  0.8169120  0.55163942  0.79640128  0.8369266
# ROUGE-1-R        0.83088633  0.6666661  0.30966228  0.61965007  0.7131389
# ROUGE-2-F1       0.78538358  0.6948715  0.43215479  0.65546906  0.7225067
# ROUGE-2-P        0.77834923  0.7069135  0.45543055  0.67051311  0.7305908
# ROUGE-2-R        0.76527333  0.6411212  0.36003650  0.59613202  0.6752764
# ROUGE-3-F1       0.69863299  0.6451148  0.46115677  0.62344010  0.6632465
# ROUGE-3-P        0.69754635  0.6473532  0.46386139  0.62621374  0.6647582
# ROUGE-3-R        0.69211547  0.6263781  0.43198642  0.60262710  0.6472739
# ROUGE-4-F1       0.58229185  0.5399727  0.42521523  0.52647858  0.5531048
# ROUGE-4-P        0.58215785  0.5404426  0.42523764  0.52702436  0.5534700
# ROUGE-4-R        0.57799517  0.5283902  0.40554220  0.51378543  0.5432600
# ROUGE-L-P        0.82067380  0.8035119  0.54410030  0.77918363  0.8232032
# ROUGE-L-R        0.82460566  0.6632658  0.31657303  0.61367416  0.7082445
# ROUGE-W-F1       0.86692712  0.7586147  0.43261045  0.71668575  0.7958996
# ROUGE-W-P        0.82355904  0.7999718  0.53330819  0.77234830  0.8212301
# ROUGE-W-R        0.80366778  0.6309139  0.27076373  0.57655412  0.6787343
# TF_IDF_ED       -0.95591177 -0.8257272 -0.46931801 -0.77911048 -0.8559919
# chrF             0.88008221  0.9305986  0.61786848  0.89904314  0.9487898
# USE_ED          -0.85749407 -0.8272664 -0.50852895 -0.79558807 -0.8528899
# SentenceBERT_ED -0.77211363 -0.7311720 -0.42322426 -0.70539011 -0.7613607
# InferSent_ED    -0.85551997 -0.8077889 -0.50308921 -0.77830596 -0.8311501
# CodeT5-plus_CS  -0.02069862  0.0739542  0.10677723  0.09836879  0.0547116
# SIDE             0.30114615  0.2813001  0.07772086  0.26097877  0.2950281
#                 BLEU-4      TF_IDF_CS   USE_CS      BERTScore-P BERTScore-R ⋯
# Jaccard          0.91130481  0.95596391  0.85751385  0.7708334   0.74611117 ⋯
# BLEU-A           0.98225952  0.82537044  0.82728548  0.7047391   0.78382722 ⋯
# BLEU-1           0.67292027  0.46914707  0.50854072  0.4575816   0.60395433 ⋯
# BLEU-2           0.94463141  0.77866528  0.79560654  0.6781502   0.76984803 ⋯
# BLEU-3           0.99219992  0.85564933  0.85290958  0.7289489   0.79199768 ⋯
# BLEU-4           1.00000000  0.87434789  0.85896250  0.7403395   0.78765499 ⋯
# TF_IDF_CS        0.87434789  1.00000000  0.81405794  0.7673517   0.73074229 ⋯
# USE_CS           0.85896250  0.81405794  1.00000000  0.7846932   0.77540183 ⋯
# BERTScore-P      0.74033947  0.76735171  0.78469322  1.0000000   0.79420824 ⋯
# BERTScore-R      0.78765499  0.73074229  0.77540183  0.7942082   1.00000000 ⋯
# BERTScore-F1     0.80205375  0.78822375  0.82210459  0.9463306   0.94371500 ⋯
# SentenceBERT_CS  0.77672449  0.74003755  0.86850356  0.7143040   0.70104198 ⋯
# InferSent_CS     0.79029628  0.80883440  0.85375592  0.7781197   0.69134523 ⋯
# METEOR           0.89771596  0.86652455  0.83897175  0.7392608   0.76548492 ⋯
# ROUGE-L-F1       0.82624381  0.83793288  0.80147610  0.7387585   0.71657446 ⋯
# c_coeff          0.25870230  0.25545517  0.36342869  0.3292305   0.20842072 ⋯
# ROUGE-1-F1       0.84070500  0.84607235  0.82357706  0.7432577   0.72518850 ⋯
# ROUGE-1-P        0.83437678  0.79184608  0.79373458  0.6498361   0.75252621 ⋯
# ROUGE-1-R        0.73496891  0.80773175  0.76387881  0.7561256   0.59618076 ⋯
# ROUGE-2-F1       0.74968417  0.75929417  0.69965751  0.6638347   0.65000059 ⋯
# ROUGE-2-P        0.75459484  0.75104989  0.69642584  0.6366384   0.66592372 ⋯
# ROUGE-2-R        0.70813671  0.74357220  0.67650872  0.6709350   0.60025643 ⋯
# ROUGE-3-F1       0.68325377  0.68048719  0.65220052  0.6345517   0.61396476 ⋯
# ROUGE-3-P        0.68423708  0.67898572  0.65247806  0.6259179   0.61662825 ⋯
# ROUGE-3-R        0.66955952  0.67553995  0.64360816  0.6350402   0.59993189 ⋯
# ROUGE-4-F1       0.56543564  0.57406829  0.54931382  0.5528162   0.52891274 ⋯
# ROUGE-4-P        0.56568299  0.57388881  0.54982427  0.5495781   0.52975346 ⋯
# ROUGE-4-R        0.55699882  0.57071448  0.54316508  0.5509961   0.52071273 ⋯
# ROUGE-L-P        0.82430710  0.78559476  0.77471034  0.6508748   0.74707694 ⋯
# ROUGE-L-R        0.73230812  0.80426521  0.74840925  0.7541222   0.59993198 ⋯
# ROUGE-W-F1       0.81267612  0.83205039  0.79647404  0.7512711   0.69511864 ⋯
# ROUGE-W-P        0.82598442  0.78656146  0.77621678  0.6531004   0.74661134 ⋯
# ROUGE-W-R        0.70707600  0.77890640  0.72946579  0.7423802   0.57561042 ⋯
# TF_IDF_ED       -0.87457685 -0.99968636 -0.81433610 -0.7668817  -0.73057421 ⋯
# chrF             0.96168349  0.84487132  0.85680463  0.7249829   0.77649294 ⋯
# USE_ED          -0.85894280 -0.81391264 -0.99953148 -0.7845902  -0.77530154 ⋯
# SentenceBERT_ED -0.76973017 -0.72531509 -0.86804051 -0.7059015  -0.69513392 ⋯
# InferSent_ED    -0.83993635 -0.83588859 -0.87231400 -0.7830962  -0.74928560 ⋯
# CodeT5-plus_CS   0.03720231 -0.04561425  0.01047038 -0.2041388  -0.02624831 ⋯
# SIDE             0.29438080  0.26926730  0.41105678  0.2786165   0.27294998 ⋯
#                 ROUGE-W-F1 ROUGE-W-P   ROUGE-W-R  TF_IDF_ED   chrF
# Jaccard          0.8669271  0.82355904  0.8036678 -0.95591177  0.88008221
# BLEU-A           0.7586147  0.79997179  0.6309139 -0.82572716  0.93059861
# BLEU-1           0.4326105  0.53330819  0.2707637 -0.46931801  0.61786848
# BLEU-2           0.7166858  0.77234830  0.5765541 -0.77911048  0.89904314
# BLEU-3           0.7958996  0.82123006  0.6787343 -0.85599192  0.94878981
# BLEU-4           0.8126761  0.82598442  0.7070760 -0.87457685  0.96168349
# TF_IDF_CS        0.8320504  0.78656146  0.7789064 -0.99968636  0.84487132
# USE_CS           0.7964740  0.77621678  0.7294658 -0.81433610  0.85680463
# BERTScore-P      0.7512711  0.65310038  0.7423802 -0.76688166  0.72498288
# BERTScore-R      0.6951186  0.74661134  0.5756104 -0.73057421  0.77649294
# BERTScore-F1     0.7607610  0.73594638  0.6932455 -0.78795530  0.78919093
# SentenceBERT_CS  0.7374887  0.70142069  0.6959701 -0.74069564  0.79771011
# InferSent_CS     0.7464291  0.69736693  0.6996507 -0.80879010  0.79125739
# METEOR           0.8485323  0.85101833  0.7585330 -0.86658991  0.88437881
# ROUGE-L-F1       0.9890119  0.94891313  0.9120296 -0.83756662  0.80871511
# c_coeff          0.3320515  0.23477219  0.3835847 -0.25371144  0.28782840
# ROUGE-1-F1       0.9659495  0.92905853  0.8893588 -0.84586155  0.82091690
# ROUGE-1-P        0.8922796  0.97556963  0.7418782 -0.79171539  0.82674094
# ROUGE-1-R        0.9368020  0.77560462  0.9701457 -0.80732140  0.71922533
# ROUGE-2-F1       0.8804620  0.83219225  0.8177699 -0.75926158  0.75280906
# ROUGE-2-P        0.8630565  0.85135484  0.7738975 -0.75101729  0.75995933
# ROUGE-2-R        0.8731996  0.77855127  0.8518658 -0.74350671  0.71502466
# ROUGE-3-F1       0.7349868  0.69969450  0.6785321 -0.68074029  0.69027254
# ROUGE-3-P        0.7308484  0.70392897  0.6674466 -0.67924110  0.69205211
# ROUGE-3-R        0.7320823  0.68553921  0.6869496 -0.67576903  0.67995172
# ROUGE-4-F1       0.6093992  0.58314057  0.5655803 -0.57473777  0.57476148
# ROUGE-4-P        0.6080529  0.58433603  0.5621410 -0.57455536  0.57530547
# ROUGE-4-R        0.6072783  0.57585047  0.5691871 -0.57136107  0.56897348
# ROUGE-L-P        0.9147064  0.99525452  0.7632974 -0.78531744  0.81610863
# ROUGE-L-R        0.9617040  0.80363604  0.9882779 -0.80376477  0.71551939
# ROUGE-W-F1       1.0000000  0.92142409  0.9514182 -0.83178852  0.79649536
# ROUGE-W-P        0.9214241  1.00000000  0.7748762 -0.78630327  0.82298559
# ROUGE-W-R        0.9514182  0.77487620  1.0000000 -0.77863448  0.69281623
# TF_IDF_ED       -0.8317885 -0.78630327 -0.7786345  1.00000000 -0.84504698
# chrF             0.7964954  0.82298559  0.6928162 -0.84504698  1.00000000
# USE_ED          -0.7955301 -0.77413024 -0.7294338  0.81433569 -0.85678474
# SentenceBERT_ED -0.7336009 -0.69814045 -0.6921306  0.72614653 -0.79267967
# InferSent_ED    -0.7892364 -0.76487996 -0.7251558  0.83652887 -0.84380777
# CodeT5-plus_CS  -0.1506365 -0.03052429 -0.2371084  0.04546031  0.02855875
# SIDE             0.2804688  0.28654419  0.2630223 -0.26883919  0.30810082
#                 USE_ED       SentenceBERT_ED InferSent_ED CodeT5-plus_CS
# Jaccard         -0.857494074 -0.7721136308   -0.85551997  -0.0206986170
# BLEU-A          -0.827266413 -0.7311720128   -0.80778894   0.0739541960
# BLEU-1          -0.508528948 -0.4232242562   -0.50308921   0.1067772296
# BLEU-2          -0.795588074 -0.7053901130   -0.77830596   0.0983687903
# BLEU-3          -0.852889893 -0.7613607274   -0.83115013   0.0547115957
# BLEU-4          -0.858942795 -0.7697301700   -0.83993635   0.0372023133
# TF_IDF_CS       -0.813912643 -0.7253150928   -0.83588859  -0.0456142524
# USE_CS          -0.999531478 -0.8680405134   -0.87231400   0.0104703793
# BERTScore-P     -0.784590158 -0.7059015206   -0.78309621  -0.2041388361
# BERTScore-R     -0.775301537 -0.6951339159   -0.74928560  -0.0262483135
# BERTScore-F1    -0.822002927 -0.7367957538   -0.80607518  -0.1178083829
# SentenceBERT_CS -0.868368340 -0.9933468195   -0.82874451   0.0024264508
# InferSent_CS    -0.853562090 -0.8029643937   -0.89805084   0.0301851526
# METEOR          -0.838563850 -0.7585290759   -0.83861292  -0.0104968200
# ROUGE-L-F1      -0.799866402 -0.7308306023   -0.79426388  -0.0985647346
# c_coeff         -0.363201463 -0.3925924574   -0.32563865  -0.1407285826
# ROUGE-1-F1      -0.821788645 -0.7491346134   -0.80864706  -0.0727602581
# ROUGE-1-P       -0.791490848 -0.7093635226   -0.77302466   0.0062956342
# ROUGE-1-R       -0.763039006 -0.7143936915   -0.75500888  -0.1681914644
# ROUGE-2-F1      -0.697209993 -0.6565816203   -0.70637539  -0.0370455788
# ROUGE-2-P       -0.693982470 -0.6462982312   -0.70242589  -0.0088648794
# ROUGE-2-R       -0.674142699 -0.6469671098   -0.68312953  -0.0720321446
# ROUGE-3-F1      -0.649788690 -0.6335916425   -0.66183238  -0.0224442633
# ROUGE-3-P       -0.650080311 -0.6314889558   -0.66046988  -0.0145610329
# ROUGE-3-R       -0.641290925 -0.6297825668   -0.65496672  -0.0338308869
# ROUGE-4-F1      -0.545371070 -0.5590929501   -0.56609516  -0.0026118133
# ROUGE-4-P       -0.545896290 -0.5590671333   -0.56573613   0.0020730159
# ROUGE-4-R       -0.539313306 -0.5569638427   -0.56214864  -0.0104414938
# ROUGE-L-P       -0.772555291 -0.6938144696   -0.76272458  -0.0189914565
# ROUGE-L-R       -0.747613706 -0.7019981782   -0.74599059  -0.1846623931
# ROUGE-W-F1      -0.795530092 -0.7336009076   -0.78923637  -0.1506364899
# ROUGE-W-P       -0.774130241 -0.6981404510   -0.76487996  -0.0305242864
# ROUGE-W-R       -0.729433815 -0.6921306484   -0.72515578  -0.2371084334
# TF_IDF_ED        0.814335686  0.7261465323    0.83652887   0.0454603145
# chrF            -0.856784739 -0.7926796662   -0.84380777   0.0285587479
# USE_ED           1.000000000  0.8680293369    0.87233257  -0.0068413921
# SentenceBERT_ED  0.868029337  1.0000000000    0.82396225   0.0008147051
# InferSent_ED     0.872332569  0.8239622467    1.00000000   0.0441367764
# CodeT5-plus_CS  -0.006841392  0.0008147051    0.04413678   1.0000000000
# SIDE            -0.408933307 -0.4028045876   -0.34640975   0.1459356264
#                 SIDE
# Jaccard          0.30114615
# BLEU-A           0.28130012
# BLEU-1           0.07772086
# BLEU-2           0.26097877
# BLEU-3           0.29502806
# BLEU-4           0.29438080
# TF_IDF_CS        0.26926730
# USE_CS           0.41105678
# BERTScore-P      0.27861654
# BERTScore-R      0.27294998
# BERTScore-F1     0.29504425
# SentenceBERT_CS  0.40496043
# InferSent_CS     0.35988549
# METEOR           0.30889725
# ROUGE-L-F1       0.29250592
# c_coeff          0.40849481
# ROUGE-1-F1       0.30307138
# ROUGE-1-P        0.29932970
# ROUGE-1-R        0.28462386
# ROUGE-2-F1       0.25002602
# ROUGE-2-P        0.25023122
# ROUGE-2-R        0.24530806
# ROUGE-3-F1       0.19555971
# ROUGE-3-P        0.19646656
# ROUGE-3-R        0.19872439
# ROUGE-4-F1       0.14168269
# ROUGE-4-P        0.14330569
# ROUGE-4-R        0.14498761
# ROUGE-L-P        0.29056493
# ROUGE-L-R        0.27376290
# ROUGE-W-F1       0.28046883
# ROUGE-W-P        0.28654419
# ROUGE-W-R        0.26302230
# TF_IDF_ED       -0.26883919
# chrF             0.30810082
# USE_ED          -0.40893331
# SentenceBERT_ED -0.40280459
# InferSent_ED    -0.34640975
# CodeT5-plus_CS   0.14593563
# SIDE             1.00000000

# %%
library(Hmisc)
v<-varclus(as.matrix(tmet,similarity="spearman",type="data.matrix"))
plot(v)
# Out:
# Loading required package: lattice
#
# Loading required package: survival
#
# Loading required package: Formula
#
# Loading required package: ggplot2
#
# Registered S3 methods overwritten by 'tibble':
#   method     from
#   format.tbl pillar
#   print.tbl  pillar
#
#
# Attaching package: ‘Hmisc’
#
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units
# plot without title

# %%
quotedEvalMetrics=c()
for(metric in evalMetrics)
{
    quotedEvalMetrics=c(quotedEvalMetrics,paste("`",metric,"`",sep=""))
}

quotedUserMetrics=c()
for(metric in userMetrics)
{
    quotedUserMetrics=c(quotedUserMetrics,paste("`",metric,"`",sep=""))
}

allmetrics=c(quotedUserMetrics,quotedEvalMetrics)

attach(tsum,warn.conflicts=FALSE)
metricsF=paste(quotedEvalMetrics,collapse="+")
fml=paste("~",metricsF,sep="")
m=redun(as.formula(fml),data=tsum,r2=0.8,nk=0)
reducedMetrics=m$In

# %%
print(reducedMetrics)
# Out:
#  [1] "BLEU-1"          "BERTScore-R"     "SentenceBERT_CS" "InferSent_CS"
#  [5] "c_coeff"         "ROUGE-1-P"       "ROUGE-4-R"       "ROUGE-W-R"
#  [9] "CodeT5-plus_CS"  "SIDE"

# %%
tred=subset(tsum,select=reducedMetrics)
pc=prcomp(tred)
print(pc)
# Out:
# Standard deviations (1, .., p=10):
#  [1] 0.58175006 0.31403948 0.22654636 0.20652764 0.15881527 0.13328004
#  [7] 0.12337339 0.10605746 0.07764883 0.06988356
#
# Rotation (n x k) = (10 x 10):
#                          PC1          PC2         PC3         PC4         PC5
# BLEU-1           0.256907582  0.240392456 -0.43553791  0.10523520 -0.49777734
# BERTScore-R      0.473145895  0.151154075 -0.23912646  0.24508992 -0.18134286
# SentenceBERT_CS  0.376209630 -0.099817065  0.04275282  0.17238658  0.21845971
# InferSent_CS     0.230583465 -0.008831151 -0.01141228  0.05606297  0.08748421
# c_coeff          0.127277704 -0.466134293  0.52989347  0.39306375 -0.54442302
# ROUGE-1-P        0.439649756  0.070671985 -0.10066299  0.21306068  0.32803615
# ROUGE-4-R        0.414195157  0.256473399  0.38293778 -0.72842440 -0.25301100
# ROUGE-W-R        0.304209887 -0.035279282  0.36132078  0.05836016  0.44045163
# CodeT5-plus_CS  -0.002563013 -0.021649279 -0.16702265 -0.07936132 -0.02685338
# SIDE             0.204523010 -0.787118063 -0.39389908 -0.39471014  0.03488413
#                         PC6         PC7         PC8         PC9        PC10
# BLEU-1           0.13208803 -0.43546396  0.45271787 -0.08972520 -0.08706189
# BERTScore-R     -0.18080986  0.73901331 -0.06953505  0.10236503 -0.09488434
# SentenceBERT_CS -0.68240825 -0.37312591 -0.17662959 -0.31678165 -0.18105442
# InferSent_CS    -0.21294910 -0.16869212  0.09706609  0.54195115  0.74758897
# c_coeff          0.13188490 -0.06539445 -0.09636413  0.06122256 -0.01150091
# ROUGE-1-P        0.62705552 -0.17171529 -0.42833444 -0.14346519  0.10881424
# ROUGE-4-R        0.01103810 -0.01559572 -0.13604190 -0.04737739  0.01699016
# ROUGE-W-R        0.15131513  0.04828585  0.64464703  0.19471395 -0.31550651
# CodeT5-plus_CS  -0.01775406 -0.23177919 -0.33554405  0.72004419 -0.52869519
# SIDE             0.07004747  0.08057027  0.10083716 -0.06675994  0.02056159

# %%
library(xtable)
xtable(pc,digits=2)
# Out:
# Attaching package: ‘xtable’
#
#
# The following objects are masked from ‘package:Hmisc’:
#
#     label, label<-
#                 PC1          PC2          PC3         PC4         PC5
# BLEU-1           0.256907582  0.240392456 -0.43553791  0.10523520 -0.49777734
# BERTScore-R      0.473145895  0.151154075 -0.23912646  0.24508992 -0.18134286
# SentenceBERT_CS  0.376209630 -0.099817065  0.04275282  0.17238658  0.21845971
# InferSent_CS     0.230583465 -0.008831151 -0.01141228  0.05606297  0.08748421
# c_coeff          0.127277704 -0.466134293  0.52989347  0.39306375 -0.54442302
# ROUGE-1-P        0.439649756  0.070671985 -0.10066299  0.21306068  0.32803615
# ROUGE-4-R        0.414195157  0.256473399  0.38293778 -0.72842440 -0.25301100
# ROUGE-W-R        0.304209887 -0.035279282  0.36132078  0.05836016  0.44045163
# CodeT5-plus_CS  -0.002563013 -0.021649279 -0.16702265 -0.07936132 -0.02685338
# SIDE             0.204523010 -0.787118063 -0.39389908 -0.39471014  0.03488413
#                 PC6         PC7         PC8         PC9         PC10
# BLEU-1           0.13208803 -0.43546396  0.45271787 -0.08972520 -0.08706189
# BERTScore-R     -0.18080986  0.73901331 -0.06953505  0.10236503 -0.09488434
# SentenceBERT_CS -0.68240825 -0.37312591 -0.17662959 -0.31678165 -0.18105442
# InferSent_CS    -0.21294910 -0.16869212  0.09706609  0.54195115  0.74758897
# c_coeff          0.13188490 -0.06539445 -0.09636413  0.06122256 -0.01150091
# ROUGE-1-P        0.62705552 -0.17171529 -0.42833444 -0.14346519  0.10881424
# ROUGE-4-R        0.01103810 -0.01559572 -0.13604190 -0.04737739  0.01699016
# ROUGE-W-R        0.15131513  0.04828585  0.64464703  0.19471395 -0.31550651
# CodeT5-plus_CS  -0.01775406 -0.23177919 -0.33554405  0.72004419 -0.52869519
# SIDE             0.07004747  0.08057027  0.10083716 -0.06675994  0.02056159

# %%
summary(pc)
xtable(summary(pc),digits=2)
# Out:
# Importance of components:
#                           PC1    PC2     PC3     PC4     PC5     PC6    PC7
# Standard deviation     0.5818 0.3140 0.22655 0.20653 0.15882 0.13328 0.1234
# Proportion of Variance 0.5535 0.1613 0.08394 0.06976 0.04125 0.02905 0.0249
# Cumulative Proportion  0.5535 0.7148 0.79879 0.86855 0.90980 0.93886 0.9637
#                           PC8     PC9    PC10
# Standard deviation     0.1061 0.07765 0.06988
# Proportion of Variance 0.0184 0.00986 0.00799
# Cumulative Proportion  0.9821 0.99201 1.00000
#                        PC1       PC2       PC3       PC4       PC5
# Standard deviation     0.5817501 0.3140395 0.2265464 0.2065276 0.1588153
# Proportion of Variance 0.5535400 0.1613000 0.0839400 0.0697600 0.0412500
# Cumulative Proportion  0.5535400 0.7148400 0.7987900 0.8685500 0.9098000
#                        PC6     PC7       PC8       PC9        PC10
# Standard deviation     0.13328 0.1233734 0.1060575 0.07764883 0.06988356
# Proportion of Variance 0.02905 0.0249000 0.0184000 0.00986000 0.00799000
# Cumulative Proportion  0.93886 0.9637500 0.9821500 0.99201000 1.00000000

# %% [markdown]
# ### Relationship between user and summarization metrics

# %%
library(MASS)

quotedReducedMetrics=c()
for(metric in reducedMetrics)
{
    quotedReducedMetrics=c(quotedReducedMetrics,paste("`",metric,"`",sep=""))
}

allmetrics=c(quotedUserMetrics,quotedReducedMetrics)

attach(tsum,warn.conflicts=FALSE)
metricsF=paste(quotedReducedMetrics,collapse="+")
fml=paste("~",metricsF,sep="")

# %% [markdown]
# ### Overall DA Score Analysis

# %%
depM="Overall DA Score"
newFormula=paste("`",depM,"`",fml,sep="")
tredDep=tsum
for(metr in reducedMetrics)
{
   tredDep[[metr]]=(tredDep[[metr]]-min(tredDep[[metr]]))*100/(max(tredDep[[metr]])-min(tredDep[[metr]]))
}
tredDep[[depM]]=as.factor(round(tredDep[[depM]]))

mod<-polr(as.formula(newFormula),data=tredDep,Hess=T)
summary(mod)
coeffs <- coef(summary(mod))
p <- pnorm(abs(coeffs[, "t value"]), lower.tail = FALSE) * 2
OR<-exp(coeffs[,"Value"])
tab<-cbind(OR=OR,coeffs, "p value" = round(p,3))
rows=length(reducedMetrics)
xtable(tab[1:rows,],digits=4)
# Out:
# Call:
# polr(formula = as.formula(newFormula), data = tredDep, Hess = T)
#
# Coefficients:
#                       Value Std. Error t value
# `BLEU-1`         -0.0009776   0.001679 -0.5822
# `BERTScore-R`     0.0029023   0.002297  1.2634
# SentenceBERT_CS   0.0056880   0.001969  2.8882
# InferSent_CS     -0.0020237   0.002510 -0.8064
# c_coeff           0.0141866   0.001238 11.4549
# `ROUGE-1-P`       0.0057602   0.001770  3.2552
# `ROUGE-4-R`       0.0024266   0.001104  2.1987
# `ROUGE-W-R`      -0.0004214   0.001696 -0.2485
# `CodeT5-plus_CS`  0.0044172   0.001740  2.5383
# SIDE              0.0203300   0.001737 11.7029
#
# Intercepts:
#        Value   Std. Error t value
# 0|1     0.3888  0.1703     2.2834
# 1|2     0.8820  0.1681     5.2453
# 2|3     1.2556  0.1674     7.4983
# 3|4     1.5595  0.1674     9.3166
# 4|5     1.7998  0.1676    10.7373
# 5|6     2.0461  0.1681    12.1740
# 6|7     2.0881  0.1682    12.4163
# 7|8     2.1208  0.1683    12.6049
# 8|9     2.1542  0.1683    12.7969
# 9|10    2.1841  0.1684    12.9685
# 10|11   2.3400  0.1688    13.8597
# 11|12   2.3795  0.1690    14.0840
# 12|13   2.4006  0.1690    14.2034
# 13|14   2.4244  0.1691    14.3386
# 14|15   2.4481  0.1692    14.4728
# 15|16   2.5039  0.1693    14.7878
# 16|17   2.5367  0.1694    14.9728
# 17|18   2.5588  0.1695    15.0967
# 18|19   2.5741  0.1695    15.1827
# 19|20   2.5855  0.1696    15.2468
# 20|21   2.7048  0.1700    15.9115
# 21|22   2.7300  0.1701    16.0516
# 22|23   2.7449  0.1701    16.1341
# 23|24   2.7616  0.1702    16.2265
# 24|25   2.7773  0.1702    16.3133
# 25|26   2.8243  0.1704    16.5725
# 26|27   2.8444  0.1705    16.6838
# 27|28   2.8618  0.1706    16.7794
# 28|29   2.8782  0.1706    16.8698
# 29|30   2.8964  0.1707    16.9698
# 30|31   2.9870  0.1710    17.4665
# 31|32   3.0023  0.1711    17.5503
# 32|33   3.0203  0.1711    17.6486
# 33|34   3.0427  0.1712    17.7710
# 34|35   3.0615  0.1713    17.8734
# 35|36   3.0991  0.1714    18.0781
# 36|37   3.1117  0.1715    18.1462
# 37|38   3.1384  0.1716    18.2916
# 38|39   3.1651  0.1717    18.4368
# 39|40   3.1873  0.1718    18.5573
# 40|41   3.2731  0.1721    19.0224
# 41|42   3.2828  0.1721    19.0750
# 42|43   3.2987  0.1722    19.1610
# 43|44   3.3111  0.1722    19.2277
# 44|45   3.3288  0.1723    19.3230
# 45|46   3.3491  0.1723    19.4324
# 46|47   3.3667  0.1724    19.5276
# 47|48   3.3931  0.1725    19.6704
# 48|49   3.4152  0.1726    19.7892
# 49|50   3.4372  0.1727    19.9078
# 50|51   3.6108  0.1733    20.8407
# 51|52   3.6420  0.1734    21.0084
# 52|53   3.6635  0.1734    21.1239
# 53|54   3.6788  0.1735    21.2059
# 54|55   3.6959  0.1735    21.2978
# 55|56   3.7293  0.1736    21.4773
# 56|57   3.7420  0.1737    21.5455
# 57|58   3.7711  0.1738    21.7013
# 58|59   3.7911  0.1738    21.8089
# 59|60   3.8130  0.1739    21.9265
# 60|61   3.9356  0.1743    22.5813
# 61|62   3.9564  0.1744    22.6920
# 62|63   3.9773  0.1744    22.8033
# 63|64   3.9965  0.1745    22.9048
# 64|65   4.0138  0.1745    22.9967
# 65|66   4.0564  0.1747    23.2229
# 66|67   4.0849  0.1748    23.3733
# 67|68   4.1115  0.1749    23.5145
# 68|69   4.1314  0.1749    23.6197
# 69|70   4.1525  0.1750    23.7309
# 70|71   4.2773  0.1754    24.3872
# 71|72   4.2972  0.1755    24.4913
# 72|73   4.3321  0.1756    24.6738
# 73|74   4.3674  0.1757    24.8585
# 74|75   4.3978  0.1758    25.0170
# 75|76   4.4945  0.1761    25.5198
# 76|77   4.5380  0.1763    25.7454
# 77|78   4.5578  0.1763    25.8476
# 78|79   4.5907  0.1764    26.0178
# 79|80   4.6146  0.1765    26.1407
# 80|81   4.8175  0.1772    27.1806
# 81|82   4.8483  0.1774    27.3373
# 82|83   4.8852  0.1775    27.5244
# 83|84   4.9102  0.1776    27.6513
# 84|85   4.9470  0.1777    27.8372
# 85|86   5.0567  0.1781    28.3847
# 86|87   5.1018  0.1783    28.6074
# 87|88   5.1272  0.1784    28.7324
# 88|89   5.1792  0.1787    28.9869
# 89|90   5.2093  0.1788    29.1332
# 90|91   5.4341  0.1799    30.2103
# 91|92   5.4658  0.1800    30.3594
# 92|93   5.5273  0.1804    30.6471
# 93|94   5.5592  0.1805    30.7948
# 94|95   5.6097  0.1808    31.0266
# 95|96   5.8225  0.1821    31.9733
# 96|97   5.8544  0.1823    32.1105
# 97|98   5.8871  0.1825    32.2501
# 98|99   5.9235  0.1828    32.4041
# 99|100  5.9703  0.1831    32.5997
#
# Residual Deviance: 41509.57
# AIC: 41729.57
#                  OR        Value         Std. Error  t value    p value
# `BLEU-1`         0.9990228 -0.0009776425 0.001679148 -0.5822254 0.560
# `BERTScore-R`    1.0029066  0.0029023415 0.002297178  1.2634379 0.206
# SentenceBERT_CS  1.0057042  0.0056880275 0.001969435  2.8881523 0.004
# InferSent_CS     0.9979784 -0.0020236742 0.002509616 -0.8063680 0.420
# c_coeff          1.0142877  0.0141866110 0.001238471 11.4549444 0.000
# `ROUGE-1-P`      1.0057769  0.0057602302 0.001769533  3.2552264 0.001
# `ROUGE-4-R`      1.0024295  0.0024265872 0.001103631  2.1987309 0.028
# `ROUGE-W-R`      0.9995787 -0.0004214146 0.001695739 -0.2485137 0.804
# `CodeT5-plus_CS` 1.0044270  0.0044171896 0.001740185  2.5383448 0.011
# SIDE             1.0205380  0.0203299828 0.001737181 11.7028563 0.000

# %% [markdown]
# ### Content Adequacy Analysis

# %%
depM="Content Adequacy"
newFormula=paste("`",depM,"`",fml,sep="")
tredDep=tsum
for(metr in reducedMetrics)
{
   tredDep[[metr]]=(tredDep[[metr]]-min(tredDep[[metr]]))*5/(max(tredDep[[metr]])-min(tredDep[[metr]]))
}


tredDep[[depM]]=as.factor(round(tredDep[[depM]]))

mod<-polr(as.formula(newFormula),data=tredDep,Hess=T)
summary(mod)
coeffs <- coef(summary(mod))
p <- pnorm(abs(coeffs[, "t value"]), lower.tail = FALSE) * 2
OR<-exp(coeffs[,"Value"])
tab<-cbind(OR=OR,coeffs, "p value" = round(p,3))
rows=length(reducedMetrics)
xtable(tab[1:rows,],digits=4)
# Out:
# Call:
# polr(formula = as.formula(newFormula), data = tredDep, Hess = T)
#
# Coefficients:
#                       Value Std. Error   t value
# `BLEU-1`         -3.333e-02    0.03466 -0.961499
# `BERTScore-R`     5.118e-02    0.04684  1.092709
# SentenceBERT_CS   1.063e-01    0.04060  2.617221
# InferSent_CS     -2.321e-05    0.05168 -0.000449
# c_coeff           3.169e-01    0.02549 12.434992
# `ROUGE-1-P`       9.013e-02    0.03644  2.473280
# `ROUGE-4-R`      -8.612e-03    0.02258 -0.381369
# `ROUGE-W-R`       4.277e-02    0.03505  1.220226
# `CodeT5-plus_CS`  1.322e-01    0.03584  3.687652
# SIDE              4.864e-01    0.03659 13.294217
#
# Intercepts:
#     Value   Std. Error t value
# 0|1  0.2609  0.1805     1.4454
# 1|2  2.9222  0.1797    16.2645
# 2|3  3.7107  0.1827    20.3061
# 3|4  4.6459  0.1862    24.9515
# 4|5  5.6634  0.1900    29.8079
#
# Residual Deviance: 16560.74
# AIC: 16590.74
#                  OR        Value         Std. Error t value       p value
# `BLEU-1`         0.9672195 -3.332984e-02 0.03466447 -0.9614986818 0.336
# `BERTScore-R`    1.0525137  5.118131e-02 0.04683894  1.0927085937 0.275
# SentenceBERT_CS  1.1121118  1.062608e-01 0.04060061  2.6172205702 0.009
# InferSent_CS     0.9999768 -2.320519e-05 0.05168016 -0.0004490155 1.000
# c_coeff          1.3728813  3.169117e-01 0.02548548 12.4349919969 0.000
# `ROUGE-1-P`      1.0943199  9.013308e-02 0.03644273  2.4732804280 0.013
# `ROUGE-4-R`      0.9914248 -8.612153e-03 0.02258219 -0.3813692130 0.703
# `ROUGE-W-R`      1.0437005  4.277256e-02 0.03505298  1.2202259736 0.222
# `CodeT5-plus_CS` 1.1413072  1.321743e-01 0.03584239  3.6876520749 0.000
# SIDE             1.6265316  4.864499e-01 0.03659109 13.2942173805 0.000

# %% [markdown]
# ### Conciseness Analysis

# %%
depM="Conciseness"
newFormula=paste("`",depM,"`",fml,sep="")
tredDep=tsum
for(metr in reducedMetrics)
{
   tredDep[[metr]]=(tredDep[[metr]]-min(tredDep[[metr]]))*5/(max(tredDep[[metr]])-min(tredDep[[metr]]))
}
tredDep[[depM]]=as.factor(round(tredDep[[depM]]))

mod<-polr(as.formula(newFormula),data=tredDep,Hess=T)
summary(mod)
coeffs <- coef(summary(mod))
p <- pnorm(abs(coeffs[, "t value"]), lower.tail = FALSE) * 2
OR<-exp(coeffs[,"Value"])
tab<-cbind(OR=OR,coeffs, "p value" = round(p,3))
rows=length(reducedMetrics)
xtable(tab[1:rows,],digits=4)
# Out:
# Call:
# polr(formula = as.formula(newFormula), data = tredDep, Hess = T)
#
# Coefficients:
#                      Value Std. Error t value
# `BLEU-1`          0.063571    0.03422  1.8576
# `BERTScore-R`     0.015868    0.04701  0.3375
# SentenceBERT_CS   0.057075    0.04030  1.4163
# InferSent_CS      0.007908    0.05111  0.1547
# c_coeff           0.217767    0.02538  8.5798
# `ROUGE-1-P`       0.007509    0.03592  0.2091
# `ROUGE-4-R`      -0.006309    0.02281 -0.2766
# `ROUGE-W-R`       0.091118    0.03458  2.6352
# `CodeT5-plus_CS`  0.061063    0.03548  1.7212
# SIDE              0.325281    0.03542  9.1835
#
# Intercepts:
#     Value   Std. Error t value
# 0|1 -0.6397  0.1786    -3.5812
# 1|2  1.2464  0.1720     7.2462
# 2|3  1.9020  0.1735    10.9648
# 3|4  2.8179  0.1761    16.0048
# 4|5  3.7577  0.1788    21.0132
#
# Residual Deviance: 16999.74
# AIC: 17029.74
#                  OR        Value        Std. Error t value    p value
# `BLEU-1`         1.0656353  0.063571106 0.03422220  1.8575987 0.063
# `BERTScore-R`    1.0159941  0.015867511 0.04701141  0.3375247 0.736
# SentenceBERT_CS  1.0587357  0.057075455 0.04029942  1.4162847 0.157
# InferSent_CS     1.0079394  0.007908021 0.05110757  0.1547329 0.877
# c_coeff          1.2432979  0.217767449 0.02538135  8.5798217 0.000
# `ROUGE-1-P`      1.0075377  0.007509443 0.03591917  0.2090650 0.834
# `ROUGE-4-R`      0.9937105 -0.006309343 0.02281075 -0.2765951 0.782
# `ROUGE-W-R`      1.0953987  0.091118425 0.03457678  2.6352494 0.008
# `CodeT5-plus_CS` 1.0629656  0.061062707 0.03547785  1.7211501 0.085
# SIDE             1.3844189  0.325280507 0.03542014  9.1834910 0.000

# %% [markdown]
# ### Fluency analysis

# %%
depM="Fluency"
newFormula=paste("`",depM,"`",fml,sep="")
tredDep=tsum
for(metr in reducedMetrics)
{
   tredDep[[metr]]=(tredDep[[metr]]-min(tredDep[[metr]]))*5/(max(tredDep[[metr]])-min(tredDep[[metr]]))
}
tredDep[[depM]]=as.factor(round(tredDep[[depM]]))

mod<-polr(as.formula(newFormula),data=tredDep,Hess=T)
summary(mod)
coeffs <- coef(summary(mod))
p <- pnorm(abs(coeffs[, "t value"]), lower.tail = FALSE) * 2
OR<-exp(coeffs[,"Value"])
tab<-cbind(OR=OR,coeffs, "p value" = round(p,3))
rows=length(reducedMetrics)
xtable(tab[1:rows,],digits=4)
# Out:
# Call:
# polr(formula = as.formula(newFormula), data = tredDep, Hess = T)
#
# Coefficients:
#                     Value Std. Error t value
# `BLEU-1`          0.06294    0.03450  1.8243
# `BERTScore-R`     0.05441    0.04675  1.1638
# SentenceBERT_CS  -0.00421    0.04036 -0.1043
# InferSent_CS      0.05286    0.05146  1.0272
# c_coeff           0.15528    0.02528  6.1437
# `ROUGE-1-P`       0.03287    0.03650  0.9004
# `ROUGE-4-R`       0.02994    0.02292  1.3061
# `ROUGE-W-R`      -0.03337    0.03475 -0.9603
# `CodeT5-plus_CS`  0.02464    0.03571  0.6902
# SIDE              0.24889    0.03588  6.9359
#
# Intercepts:
#     Value   Std. Error t value
# 0|1 -1.2748  0.1820    -7.0050
# 1|2  0.4726  0.1743     2.7116
# 2|3  1.1007  0.1749     6.2941
# 3|4  1.8561  0.1760    10.5428
# 4|5  2.6678  0.1778    15.0034
#
# Residual Deviance: 16767.80
# AIC: 16797.80
#                  OR        Value        Std. Error t value    p value
# `BLEU-1`         1.0649641  0.062941091 0.03450193  1.8242773 0.068
# `BERTScore-R`    1.0559123  0.054405119 0.04674661  1.1638304 0.244
# SentenceBERT_CS  0.9957989 -0.004209986 0.04035709 -0.1043184 0.917
# InferSent_CS     1.0542868  0.052864496 0.05146317  1.0272298 0.304
# c_coeff          1.1679885  0.155283006 0.02527516  6.1436992 0.000
# `ROUGE-1-P`      1.0334140  0.032867882 0.03650445  0.9003802 0.368
# `ROUGE-4-R`      1.0303915  0.029938842 0.02292150  1.3061466 0.192
# `ROUGE-W-R`      0.9671830 -0.033367515 0.03474824 -0.9602650 0.337
# `CodeT5-plus_CS` 1.0249494  0.024643262 0.03570569  0.6901775 0.490
# SIDE             1.2825953  0.248885633 0.03588391  6.9358561 0.000

# %% [markdown]
# ### Aggregated evaluation

# %%
attach(tsum,warn.conflicts=FALSE)
Overall=(`Content Adequacy`+Fluency+Conciseness)/3

# %%
cor.test(Overall,`Overall DA Score`,method="spearman")
# Out:
# Warning message in cor.test.default(Overall, `Overall DA Score`, method = "spearman"):
# “Cannot compute exact p-value with ties”
# 	Spearman's rank correlation rho
#
# data:  Overall and Overall DA Score
# S = 5310443288, p-value < 2.2e-16
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.7735244

# %%
depM="Overall"
newFormula=paste(depM,fml,sep="")
tredDep=tsum
for(metr in reducedMetrics)
{
   tredDep[[metr]]=(tredDep[[metr]]-min(tredDep[[metr]]))*5/(max(tredDep[[metr]])-min(tredDep[[metr]]))
}
tsum=cbind(tsum,Overall)
tredDep[[depM]]=as.factor(round(tredDep[[depM]]))
mod<-polr(as.formula(newFormula),data=tredDep,Hess=T)
summary(mod)
coeffs <- coef(summary(mod))
p <- pnorm(abs(coeffs[, "t value"]), lower.tail = FALSE) * 2
OR<-exp(coeffs[,"Value"])
tab<-cbind(OR=OR,coeffs, "p value" = round(p,3))
rows=length(reducedMetrics)
xtable(tab[1:rows,],digits=4)
# Out:
# Call:
# polr(formula = as.formula(newFormula), data = tredDep, Hess = T)
#
# Coefficients:
#                     Value Std. Error  t value
# `BLEU-1`         0.042087    0.03447  1.22108
# `BERTScore-R`    0.058749    0.04662  1.26022
# SentenceBERT_CS  0.057306    0.04028  1.42258
# InferSent_CS     0.009932    0.05138  0.19331
# c_coeff          0.268523    0.02517 10.66685
# `ROUGE-1-P`      0.044084    0.03627  1.21541
# `ROUGE-4-R`      0.001151    0.02278  0.05054
# `ROUGE-W-R`      0.042384    0.03503  1.20983
# `CodeT5-plus_CS` 0.073617    0.03543  2.07805
# SIDE             0.382777    0.03530 10.84391
#
# Intercepts:
#     Value   Std. Error t value
# 0|1 -0.3927  0.1792    -2.1910
# 1|2  1.3170  0.1709     7.7079
# 2|3  2.3667  0.1731    13.6760
# 3|4  3.4295  0.1764    19.4378
# 4|5  4.8204  0.1813    26.5837
#
# Residual Deviance: 16773.56
# AIC: 16803.56
#                  OR       Value       Std. Error t value    p value
# `BLEU-1`         1.042985 0.042087214 0.03446711  1.2210833 0.222
# `BERTScore-R`    1.060509 0.058748738 0.04661770  1.2602240 0.208
# SentenceBERT_CS  1.058979 0.057305526 0.04028287  1.4225779 0.155
# InferSent_CS     1.009981 0.009931536 0.05137689  0.1933075 0.847
# c_coeff          1.308031 0.268523018 0.02517361 10.6668476 0.000
# `ROUGE-1-P`      1.045070 0.044084267 0.03627106  1.2154117 0.224
# `ROUGE-4-R`      1.001152 0.001151340 0.02277945  0.0505429 0.960
# `ROUGE-W-R`      1.043295 0.042384385 0.03503333  1.2098303 0.226
# `CodeT5-plus_CS` 1.076395 0.073617202 0.03542612  2.0780487 0.038
# SIDE             1.466351 0.382776748 0.03529878 10.8439098 0.000

# %% [markdown]
# ### Correlation among all metrics

# %%
attach(tsum,warn.conflicts=FALSE)

tx<-subset(tsum,select=allMetrics)
cor(tx,method="spearman")
